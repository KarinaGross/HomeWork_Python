# %% [raw]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
# Определяем корни

from sympy import *

x = Symbol('x')
expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30

a = solveset(expr, x, domain=S.Reals)
b = Interval(5*pi, 7*pi)
Intersection(a,b)
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Interval(5*pi, 7*pi))

# %%
# Нахождение экстпемумов функции на промежутке (16, 21)

from sympy import *
x = Symbol('x')
expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30
diff_expr = diff(expr, x)
# extrem = [item in item for sympy.solve(diff_expr, x)]
# cond = And(x>16, x<22)
roots = solveset(diff_expr, x)
intrvl = Interval(16, 22)
# interv = ConditionSet(x, Eq(diff_expr, 0), Interval(16, 22))

Intersection(roots, intrvl)
# Out:
# ConditionSet(x, Eq(12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10, 0), Interval(16, 22))

# %%
from sympy.plotting import plot 
from sympy import * 

x = Symbol('x') 
expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30
plot(expr, (x, 5*pi, 7*pi), line_color='green')

# %%
# График производной
from sympy.plotting import plot 
from sympy import * 

x = Symbol('x') 
expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30
diff_expr = diff(expr, x)
plot(diff_expr, (x, 5*pi, 7*pi), line_color='blue')

# %%
# Убывание и возрастание
from sympy import *

x = Symbol('x')
expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30
diff_expr = diff(expr, x)

# Находим х-координату точки экстремума с помощью цикла while, промежуток задаем от 19 д0 19.5 (исходя из графика производной функции)
start = 19
eps = 0.00001
roots = [] # значения х, при которых производная функции приблизительно равна 0

# while start < 19.5:
#     if -1 <= int(diff_expr.subs(x, start)) <= 1:
#         roots.append(start)
#     start += eps

root = 19.16747999999366 # уже вычисленное значение roots

print(f"На промежутке ({5*pi}, {7*pi}) функция убывает на интервале ({5*pi}, {root}) и возрастает на интервале ({root}, {7*pi}).")
# Out:
# На промежутке (5*pi, 7*pi) функция убывает на интервале (5*pi, 19.16747999999366) и возрастает на интервале (19.16747999999366, 7*pi).

# %%
# Вычисление вершины на промежутке (5*pi, 7*pi)

from sympy import *

x = Symbol('x') 
expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30
root = 19.16747999999366
y = expr.subs(x, root) # -1442159.56882901 - в целом, похоже, если переставить точку на 6 знаков влево


print(f"Вершина графика функции на промежутке ({5*pi}, {7*pi}) имеет координаты: ({root}, {y})")
# Out:
# Вершина графика функции на промежутке (5*pi, 7*pi) имеет координаты: (19.16747999999366, -1442159.56882901)

# %%
# Корни

from sympy import *

def look_for_roots(expr, start, end, eps=0.00001):
    x = Symbol('x')
    roots = [] 

    while start < end:
        if -1 <= int(expr.subs(x, start)) <= 1:
            roots.append(start)
        start += eps
    return roots

expr = -12 * x**4 * sin(cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30

# Перебор чисел длится не быстро, поэтому запишу сразу ответ

# x1 = look_for_roots(expr, 17, 17.5) # 17.1928499999927
# x2 = look_for_roots(expr, 20, 21) # 20.49259999998135


print(f'x1 = 17.1928499999927\nx2 = 20.49259999998135')
# Out:
# x1 = 17.1928499999927
# x2 = 20.49259999998135

# %%
# f > 0, f < 0
from sympy import oo, pi
a = (- oo, 17.1928499999927)
b = (17.1928499999927, 20.49259999998135)
c = (20.49259999998135, + oo)
print(f'На промежутке ({5*pi}, {7*pi})\nf > 0 на {a} и {c}\nf < 0 на {b}')
# Out:
# На промежутке (5*pi, 7*pi)
# f > 0 на (-oo, 17.1928499999927) и (20.49259999998135, oo)
# f < 0 на (17.1928499999927, 20.49259999998135)
